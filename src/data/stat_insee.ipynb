# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collect import load_insee_dossier_complet  # ta fonction de collecte

# Charger les données
url_insee = "https://www.insee.fr/fr/statistiques/fichier/5359146/dossier_complet.zip"
insee = load_insee_dossier_complet(url_insee)

# Vérifier que c'est bien chargé
print(insee.shape)
insee.head()
